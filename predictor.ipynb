# %%
# centimeter to inch = centimeter_value / 2.54
import pandas as pd
import matplotlib.pyplot as plt
import random

# %%
df = pd.read_csv('datasets/measurements.csv')
df = df.drop(columns=['subject_id'])
df = df / 2.54
df.head()
# Out:
#        ankle  arm-length      bicep       calf      chest    forearm  \
# 0   9.584234   20.827708  13.108030  15.239965  40.364576  10.865785
# 1   8.662119   18.410722  11.137390  14.035419  39.076140   9.769045
# 2  10.458664   20.979763  12.126362  15.690925  40.311525  10.913305
# 3   9.755735   19.321949  13.627210  15.001680  43.765382  11.240319
# 4   8.184588   16.625810   9.656355  11.488723  36.861330   8.653165
#
#       height        hip  leg-length  shoulder-breadth  shoulder-to-crotch  \
# 0  69.925588  42.538242   32.179699         14.140036           26.728848
# 1  64.716387  36.271136   29.577661         13.326290           23.835191
# 2  72.330253  41.749654   33.092727         14.904117           28.348181
# 3  66.558706  43.121837   29.255998         15.038504           26.982958
# 4  57.683713  34.304765   26.484197         12.464251           20.746959
#
#        thigh      waist     wrist
# 0  22.784565  36.333138  6.578398
# 1  20.637134  34.373189  5.981117
# 2  20.840191  38.030084  7.061653
# 3  23.093179  40.706740  6.704669
# 4  16.474387  29.291676  5.952780

# %% [markdown]
# ### Essential Measurements for difficult measurement (waist and chest) prediction:
# #### Chest:
#  - shoulder distance
#  - torso height
#  - leg length
#  - shoulder - torso (will have to add to our dataframe)
#
# #### Waist:
#  - Torso height
#  - Shoulder distance
#  - leg length
#  - chest circumference
#  - torso height - leg length (need to add)

# %%
# Adding a few extra columns as necessary 
df['torso'] = random.choice([0.85, 0.86, 0.87, 0.88, 0.89, 0.9]) * df['shoulder-to-crotch'] # Since no explicit shoulder to waist
df['shoulder-to-torso'] = df['shoulder-breadth'] / df['torso']
df['torso-to-leg-length'] = df['torso'] / df['leg-length']
df
# Out:
#           ankle  arm-length      bicep       calf      chest    forearm  \
# 0      9.584234   20.827708  13.108030  15.239965  40.364576  10.865785
# 1      8.662119   18.410722  11.137390  14.035419  39.076140   9.769045
# 2     10.458664   20.979763  12.126362  15.690925  40.311525  10.913305
# 3      9.755735   19.321949  13.627210  15.001680  43.765382  11.240319
# 4      8.184588   16.625810   9.656355  11.488723  36.861330   8.653165
# ...         ...         ...        ...        ...        ...        ...
# 2013  11.025511   17.560172  15.080146  16.944900  48.385617  11.423360
# 2014   8.860092   19.823642   9.997872  13.386337  34.610151   9.232215
# 2015  10.208698   21.057949  13.272377  14.442534  40.886229  11.285359
# 2016  10.075365   22.616275  11.919605  15.159649  39.900868  10.648586
# 2017   9.462052   18.598906  11.696608  15.027189  39.224456  10.584338
#
#          height        hip  leg-length  shoulder-breadth  shoulder-to-crotch  \
# 0     69.925588  42.538242   32.179699         14.140036           26.728848
# 1     64.716387  36.271136   29.577661         13.326290           23.835191
# 2     72.330253  41.749654   33.092727         14.904117           28.348181
# 3     66.558706  43.121837   29.255998         15.038504           26.982958
# 4     57.683713  34.304765   26.484197         12.464251           20.746959
# ...         ...        ...         ...               ...                 ...
# 2013  62.523044  49.622039   28.665834         13.933659           24.078974
# 2014  64.954713  36.478800   30.224423         13.886905           22.982315
# 2015  73.242722  40.952466   33.648739         15.077535           28.062193
# 2016  75.488173  38.395832   35.642068         15.137495           28.057092
# 2017  65.741802  38.780933   29.704080         14.311116           25.080744
#
#           thigh      waist     wrist      torso  shoulder-to-torso  \
# 0     22.784565  36.333138  6.578398  24.055963           0.587798
# 1     20.637134  34.373189  5.981117  21.451672           0.621224
# 2     20.840191  38.030084  7.061653  25.513363           0.584169
# 3     23.093179  40.706740  6.704669  24.284662           0.619259
# 4     16.474387  29.291676  5.952780  18.672264           0.667528
# ...         ...        ...       ...        ...                ...
# 2013  26.681849  45.520359  7.230346  21.671077           0.642961
# 2014  18.518284  30.940727  6.222986  20.684084           0.671381
# 2015  21.496154  35.179505  7.290345  25.255973           0.596989
# 2016  20.070624  34.002899  6.696160  25.251383           0.599472
# 2017  21.497821  31.738104  6.389065  22.572670           0.634002
#
#       torso-to-leg-length
# 0                0.747551
# 1                0.725266
# 2                0.770966
# 3                0.830075
# 4                0.705034
# ...                   ...
# 2013             0.755990
# 2014             0.684350
# 2015             0.750577
# 2016             0.708471
# 2017             0.759918
#
# [2018 rows x 17 columns]

# %%
# High positive is strong correlation, high negative is strong negative correlation, closer to zero is no correlation.
correlation_matrix = df.corr()
print(correlation_matrix)
# Out:
#                         ankle  arm-length     bicep      calf     chest  \
# ankle                1.000000    0.564986  0.633259  0.761867  0.652193
# arm-length           0.564986    1.000000  0.259321  0.268386  0.310361
# bicep                0.633259    0.259321  1.000000  0.733878  0.851243
# calf                 0.761867    0.268386  0.733878  1.000000  0.724248
# chest                0.652193    0.310361  0.851243  0.724248  1.000000
# forearm              0.776667    0.459968  0.888790  0.732418  0.809597
# height               0.696257    0.913150  0.375072  0.414201  0.414684
# hip                  0.583440    0.206780  0.803162  0.747231  0.847984
# leg-length           0.521137    0.928655  0.216887  0.236512  0.258911
# shoulder-breadth     0.753634    0.657104  0.670657  0.580747  0.719742
# shoulder-to-crotch   0.778602    0.762108  0.531557  0.545078  0.579490
# thigh                0.575876    0.164011  0.821548  0.794774  0.760533
# waist                0.621294    0.278186  0.793691  0.711414  0.926662
# wrist                0.823873    0.487904  0.753542  0.700484  0.759588
# torso                0.778602    0.762108  0.531557  0.545078  0.579490
# shoulder-to-torso   -0.019217   -0.181071  0.297855  0.091051  0.302853
# torso-to-leg-length  0.451837   -0.022915  0.468430  0.460504  0.482718
#
#                       forearm    height       hip  leg-length  \
# ankle                0.776667  0.696257  0.583440    0.521137
# arm-length           0.459968  0.913150  0.206780    0.928655
# bicep                0.888790  0.375072  0.803162    0.216887
# calf                 0.732418  0.414201  0.747231    0.236512
# chest                0.809597  0.414684  0.847984    0.258911
# forearm              1.000000  0.580294  0.684757    0.396236
# height               0.580294  1.000000  0.310025    0.909589
# hip                  0.684757  0.310025  1.000000    0.187699
# leg-length           0.396236  0.909589  0.187699    1.000000
# shoulder-breadth     0.829782  0.747583  0.508744    0.540411
# shoulder-to-crotch   0.717519  0.901101  0.453305    0.673379
# thigh                0.692189  0.268541  0.892160    0.160498
# waist                0.744364  0.388765  0.880308    0.228417
# wrist                0.882579  0.604498  0.651970    0.431043
# torso                0.717519  0.901101  0.453305    0.673379
# shoulder-to-torso    0.250168 -0.273074  0.130708   -0.241378
# torso-to-leg-length  0.513346  0.180204  0.393903   -0.218983
#
#                      shoulder-breadth  shoulder-to-crotch     thigh     waist  \
# ankle                        0.753634            0.778602  0.575876  0.621294
# arm-length                   0.657104            0.762108  0.164011  0.278186
# bicep                        0.670657            0.531557  0.821548  0.793691
# calf                         0.580747            0.545078  0.794774  0.711414
# chest                        0.719742            0.579490  0.760533  0.926662
# forearm                      0.829782            0.717519  0.692189  0.744364
# height                       0.747583            0.901101  0.268541  0.388765
# hip                          0.508744            0.453305  0.892160  0.880308
# leg-length                   0.540411            0.673379  0.160498  0.228417
# shoulder-breadth             1.000000            0.872256  0.458538  0.658764
# shoulder-to-crotch           0.872256            1.000000  0.384957  0.572474
# thigh                        0.458538            0.384957  1.000000  0.743533
# waist                        0.658764            0.572474  0.743533  1.000000
# wrist                        0.780835            0.723079  0.614537  0.726042
# torso                        0.872256            1.000000  0.384957  0.572474
# shoulder-to-torso            0.287615           -0.216051  0.162745  0.196176
# torso-to-leg-length          0.555432            0.572411  0.335399  0.504986
#
#                         wrist     torso  shoulder-to-torso  \
# ankle                0.823873  0.778602          -0.019217
# arm-length           0.487904  0.762108          -0.181071
# bicep                0.753542  0.531557           0.297855
# calf                 0.700484  0.545078           0.091051
# chest                0.759588  0.579490           0.302853
# forearm              0.882579  0.717519           0.250168
# height               0.604498  0.901101          -0.273074
# hip                  0.651970  0.453305           0.130708
# leg-length           0.431043  0.673379          -0.241378
# shoulder-breadth     0.780835  0.872256           0.287615
# shoulder-to-crotch   0.723079  1.000000          -0.216051
# thigh                0.614537  0.384957           0.162745
# waist                0.726042  0.572474           0.196176
# wrist                1.000000  0.723079           0.142851
# torso                0.723079  1.000000          -0.216051
# shoulder-to-torso    0.142851 -0.216051           1.000000
# torso-to-leg-length  0.480041  0.572411          -0.009897
#
#                      torso-to-leg-length
# ankle                           0.451837
# arm-length                     -0.022915
# bicep                           0.468430
# calf                            0.460504
# chest                           0.482718
# forearm                         0.513346
# height                          0.180204
# hip                             0.393903
# leg-length                     -0.218983
# shoulder-breadth                0.555432
# shoulder-to-crotch              0.572411
# thigh                           0.335399
# waist                           0.504986
# wrist                           0.480041
# torso                           0.572411
# shoulder-to-torso              -0.009897
# torso-to-leg-length             1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create a heatmap for the correlation matrix
plt.figure(figsize=(12,10))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)

plt.title("Correlation Matrix Heatmap")
plt.show()

# %%
waist_corr = correlation_matrix['waist'].sort_values(ascending=False)
chest_corr = correlation_matrix['chest'].sort_values(ascending=False)

print((chest_corr))
# print(waist_corr)
# Out:
# chest                  1.000000
# waist                  0.926662
# bicep                  0.851243
# hip                    0.847984
# forearm                0.809597
# thigh                  0.760533
# wrist                  0.759588
# calf                   0.724248
# shoulder-breadth       0.719742
# ankle                  0.652193
# shoulder-to-crotch     0.579490
# torso                  0.579490
# torso-to-leg-length    0.482718
# height                 0.414684
# arm-length             0.310361
# shoulder-to-torso      0.302853
# leg-length             0.258911
# Name: chest, dtype: float64

# %%
print(waist_corr)
# Out:
# waist                  1.000000
# chest                  0.926662
# hip                    0.880308
# bicep                  0.793691
# forearm                0.744364
# thigh                  0.743533
# wrist                  0.726042
# calf                   0.711414
# shoulder-breadth       0.658764
# ankle                  0.621294
# torso                  0.572474
# shoulder-to-crotch     0.572474
# torso-to-leg-length    0.504986
# height                 0.388765
# arm-length             0.278186
# leg-length             0.228417
# shoulder-to-torso      0.196176
# Name: waist, dtype: float64

# %% [markdown]
# From the above, we can use
# ### Waist:
#     - Forearm (0.744)
#     - Thigh (0.743)
#     - Calf (0.711)
#     - Shoulder-breadth (0.658)
#     - Torso-leg-length (0.504)
#
# ### Chest:
#     - Forearm (0.809)
#     - Thigh (0.760)
#     - Calf (0.724)
#     - Shoulder-Breadth (0.719)
#     - Torso-leg-length ((0.483))

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
import pandas as pd

# Example: Your feature DataFrame
X = df[['forearm', 'thigh', 'calf', 'shoulder-breadth', 'torso-to-leg-length']]  

# Compute VIF
vif_data = pd.DataFrame()
vif_data["Feature"] = X.columns
vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

print(vif_data)
# Out:
#                Feature         VIF
# 0              forearm  506.597659
# 1                thigh  324.665241
# 2                 calf  470.260932
# 3     shoulder-breadth  597.892481
# 4  torso-to-leg-length  299.189298

# %%
optimized_df = df.drop(columns=['bicep', 'hip', 'wrist', 'leg-length', 'shoulder-to-torso', 'arm-length', 'height', 'torso', 'shoulder-to-crotch', 'ankle'])
x_train_chest = df[['calf', 'forearm', 'shoulder-breadth', 'thigh']]
x_train_waist = df[['calf', 'forearm', 'shoulder-breadth', 'thigh', 'torso-to-leg-length']]
y_train_chest = df['chest']
y_train_waist = df['waist']

# %%
from sklearn.linear_model import RidgeCV

# Specify possible alphas to test
alphas = [0.1, 1, 10, 100, 1000]

# Fit a Ridge regression model with cross-validation
ridge_model = RidgeCV(alphas=alphas, store_cv_values=True)
ridge_model.fit(x_train_waist, y_train_waist)

# Get the best alpha
best_alpha = ridge_model.alpha_
print(f"Optimal Alpha: {best_alpha}")
# Out:
# Optimal Alpha: 0.1
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:2341: FutureWarning: 'store_cv_values' is deprecated in version 1.5 and will be removed in 1.7. Use 'store_cv_results' instead.
#   warnings.warn(

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_squared_error, r2_score
import sklearn

print(sklearn.__version__)
# Step 1: Split your data into 90% training and 10% testing
X_train, X_test, y_train, y_test = train_test_split(x_train_chest, y_train_chest, test_size=0.1, random_state=42)

# Step 2: Create a Ridge regression model with the given alpha
chest_model = Ridge(alpha=10)

# Step 3: Fit the model to the training data
chest_model.fit(X_train, y_train)

# Step 4: Make predictions on the test set
y_pred = chest_model.predict(X_test)

# Step 5: Evaluate the model
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error (MSE): {mse}")
print(f"R-squared (R²): {r2}")
# Out:
# 1.5.1
# Mean Squared Error (MSE): 4.170099938990403
# R-squared (R²): 0.7648561318229261

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_squared_error, r2_score

# Step 1: Split your data into 90% training and 10% testing
X_train, X_test, y_train, y_test = train_test_split(x_train_waist, y_train_waist, test_size=0.1, random_state=42)

# Step 2: Create a Ridge regression model with the given alpha
waist_model = Ridge(alpha=0.1)

# Step 3: Fit the model to the training data
waist_model.fit(X_train, y_train)

print(y_train)
# Step 4: Make predictions on the test set
y_pred = waist_model.predict(X_test)
print(y_pred[0])

# Step 5: Evaluate the model
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error (MSE): {mse}")
print(f"R-squared (R²): {r2}")
# Out:
# 49      35.524356
# 210     38.746400
# 1100    30.388416
# 1358    33.018962
# 1244    35.487306
#           ...
# 1130    39.097133
# 1294    36.149177
# 860     34.658702
# 1459    35.986013
# 1126    39.835931
# Name: waist, Length: 1816, dtype: float64
# 41.974805140669964
# Mean Squared Error (MSE): 7.67503594788549
# R-squared (R²): 0.6929502421066349

# %%
import pickle

# Save the trained model
with open('waist_model.pkl', 'wb') as file:
    pickle.dump(waist_model, file)

# %%
with open('chest_model.pkl', 'wb') as file:
    pickle.dump(chest_model, file)

# %%
with open('models/chest_model.pkl', 'rb') as f:
    chest_model = pickle.load(f)

with open('models/waist_model.pkl', 'rb') as f:
    waist_model = pickle.load(f)

output = chest_model.predict([[10, 20, 30, 40]])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but Ridge was fitted with feature names
#   warnings.warn(
